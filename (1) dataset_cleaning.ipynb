# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/drom_archive_2007-2025.csv')
# Out:
# C:\Users\Sofia\AppData\Local\Temp\ipykernel_14892\3918915559.py:1: DtypeWarning: Columns (0: Цвет, 1: VIN, 2: Проверено, 3: Номер кузова, 4: Владельцы) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('drom_archive_2007-2025.csv')

# %%
df.shape
# Out:
# (12147688, 58)

# %%
df.head()
# Out:
#     Название машины     Год  \
# 0  Aston Martin DB9  2009.0
# 1  Aston Martin DBS  2008.0
# 2  Aston Martin DB9  2004.0
# 3  Aston Martin DB9  2005.0
# 4  Aston Martin DB9  2005.0
#
#                                               Ссылка  \
# 0  https://auto.drom.ru/vladivostok/aston_martin/...
# 1  https://auto.drom.ru/moscow/aston_martin/dbs/9...
# 2  https://auto.drom.ru/krasnodar/aston_martin/db...
# 3  https://auto.drom.ru/moscow/aston_martin/db9/1...
# 4  https://auto.drom.ru/moscow/aston_martin/db9/1...
#
#   Дата размещения объявления       Цена  Кол-во просмотров  Скрыто  \
# 0                 2012-12-06  7876735.0               30.0     0.0
# 1                 2013-01-29  9000000.0              763.0     0.0
# 2                 2015-11-29  1985000.0              363.0     0.0
# 3                 2015-10-22  2586000.0              293.0     0.0
# 4                 2015-10-26  2304000.0              464.0     0.0
#
#    Объем двигателя Тип двигателя  Мощность  ... Объем ковша Длина стрелы  \
# 0              5.9        бензин     477.0  ...         NaN          NaN
# 1              5.9        бензин     517.0  ...         NaN          NaN
# 2              5.9        бензин     456.0  ...         NaN          NaN
# 3              5.9        бензин     456.0  ...         NaN          NaN
# 4              5.9        бензин     456.0  ...         NaN          NaN
#
#    Грузоподъемность стрелы Высота вышки  Состояние  Страна производства  \
# 0                      NaN          NaN        NaN                  NaN
# 1                      NaN          NaN        NaN                  NaN
# 2                      NaN          NaN        NaN                  NaN
# 3                      NaN          NaN        NaN                  NaN
# 4                      NaN          NaN        NaN                  NaN
#
#   Высота подъема Ошибка_ст Ошибка_знач    Пропуски в данных
# 0            NaN       7,        6.0,   9, 14, 15, 17, 20,
# 1            NaN       NaN         NaN      9, 14, 15, 17,
# 2            NaN       9,      450.0,          14, 15, 17,
# 3            NaN       9,      450.0,          14, 15, 17,
# 4            NaN       9,      450.0,          14, 15, 17,
#
# [5 rows x 58 columns]

# %%
# удалим ненужные столбцы
drp = [
    "Ссылка", "VIN", "Номер кузова",
    "Ошибка_ст", "Ошибка_знач", "Скрыто", "Проверено",
    "Кол-во просмотров", "Комплектация",
    "Особые отметки",
    "Рефрижератор", "Спальник", "Объем кузова",
    "Категория ТС", "Тип техники", "Колёсная формула",
    "Количество осей", "Масса", "Грузоподъемность",
    "Длина кузова", "Тип кабины", "Рабочая ширина",
    "Моточасы", "Оборудование", "Высота седла",
    "Бренд ХОУ", "Объем ковша", "Длина стрелы",
    "Грузоподъемность стрелы", "Высота вышки",
    "Высота подъема", "Ходовая часть",
    "Владелец","Топливо", "Регион", "Макро-регион", "Цвет", "Состояние", "Страна производства", "Количество мест", "Владельцы", "Пропуски в данных"
]

df = df.drop(columns=drp, errors="ignore")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12147688 entries, 0 to 12147687
# Data columns (total 16 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Название машины             str
#  1   Год                         float64
#  2   Дата размещения объявления  str
#  3   Цена                        float64
#  4   Объем двигателя             float64
#  5   Тип двигателя               str
#  6   Мощность                    float64
#  7   Коробка передач             str
#  8   Привод                      str
#  9   Пробег                      float64
#  10  Руль                        str
#  11  Поколение                   float64
#  12  Рестайлинг                  float64
#  13  Тип кузова                  str
#  14  Метка                       str
#  15  Город                       str
# dtypes: float64(7), str(9)
# memory usage: 1.4 GB

# %%
list(df['Тип кузова'].unique())
# Out:
# ['купе//открытый кузов',
#  'купе',
#  'открытый',
#  'лифтбек',
#  nan,
#  'открытый кузов',
#  'джип/suv 5 дв.',
#  'седан',
#  'хэтчбек 3 дв.',
#  'хэтчбек 5 дв.',
#  'седан//универсал',
#  'открытый кузов//седан//универсал',
#  'универсал',
#  'открытый кузов//хэтчбек 3 дв.',
#  'купе//седан',
#  'купе//лифтбек//открытый кузов',
#  'хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//открытый кузов',
#  'купе//лифтбек',
#  'седан//хэтчбек 3 дв.',
#  'открытый кузов//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//седан',
#  'открытый кузов//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'седан//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//седан',
#  'открытый кузов//седан//хэтчбек 5 дв.',
#  'седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//лифтбек//седан',
#  'купе//открытый кузов//седан',
#  'купе//лифтбек//седан//универсал',
#  'купе//открытый кузов//седан//универсал',
#  'джип/suv 5 дв.//купе//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//седан//универсал',
#  'купе//лифтбек//открытый кузов//седан//универсал',
#  'лифтбек//седан//универсал',
#  'джип/suv 5 дв.//купе//лифтбек//открытый кузов//седан//универсал',
#  'джип/suv 5 дв.//седан//универсал',
#  'купе//лифтбек//универсал',
#  'открытый кузов//универсал',
#  'джип/suv 5 дв.//купе//открытый кузов//седан//универсал',
#  'джип/suv 5 дв.//купе//лифтбек//седан//универсал',
#  'купе//лифтбек//открытый кузов//седан//универсал//хэтчбек 5 дв.',
#  'купе//универсал',
#  'купе//открытый кузов//универсал',
#  'купе//открытый кузов//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//лифтбек//открытый кузов//седан',
#  'минивэн',
#  'минивэн//хэтчбек 5 дв.',
#  'купе//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//открытый кузов//хэтчбек 5 дв.',
#  'лифтбек//универсал',
#  'минивэн//седан',
#  'джип/suv 5 дв.//минивэн',
#  'джип/suv 5 дв.//пикап',
#  'пикап',
#  'джип/suv 5 дв.//минивэн//седан',
#  'джип/suv 5 дв.//лифтбек',
#  'джип/suv 5 дв.//лифтбек//седан//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//минивэн//седан//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//седан//хэтчбек 5 дв.',
#  'лифтбек//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//седан',
#  'лифтбек//седан//хэтчбек 5 дв.',
#  'седан//универсал//хэтчбек 5 дв.',
#  'универсал//хэтчбек 5 дв.',
#  'минивэн//седан//универсал//хэтчбек 5 дв.',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//седан',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап//седан//цельнометаллический фургон',
#  'автобус//джип/suv 5 дв.//цельнометаллический фургон',
#  'джип/suv 5 дв.//пикап//цельнометаллический фургон',
#  'джип/suv 3 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//пикап',
#  'джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап//седан//универсал',
#  'автобус//цельнометаллический фургон',
#  'джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал',
#  'цельнометаллический фургон',
#  'джип/suv 3 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал',
#  'джип/suv 3 дв.//джип/suv 5 дв.',
#  'купе//седан//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//купе//седан//универсал//хэтчбек 3 дв.',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//цельнометаллический фургон',
#  'джип/suv 3 дв.//купе//лифтбек//минивэн//открытый кузов//пикап',
#  'джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап',
#  'автобус//джип/suv 5 дв.//купе//лифтбек//открытый кузов//цельнометаллический фургон',
#  'джип/suv 3 дв.//купе//лифтбек//пикап//седан//универсал',
#  'джип/suv 5 дв.//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//открытый кузов//седан//универсал//цельнометаллический фургон',
#  'джип/suv 3 дв.//купе//минивэн//пикап//седан',
#  'купе//минивэн//открытый кузов//седан',
#  'джип/suv 5 дв.//купе//открытый кузов',
#  'универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//хэтчбек 5 дв.',
#  'минивэн//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//универсал',
#  'минивэн//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//открытый кузов//хэтчбек 5 дв.',
#  'универсал//хэтчбек 3 дв.',
#  'минивэн//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//седан//универсал//хэтчбек 3 дв.',
#  'минивэн//седан//универсал',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'джип/suv 3 дв.//пикап',
#  'купе//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//универсал//хэтчбек 3 дв.',
#  'купе//лифтбек//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'автобус//лифтбек//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон',
#  'минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//открытый кузов//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//лифтбек//седан//хэтчбек 3 дв.',
#  'открытый кузов//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//пикап//седан//универсал//хэтчбек 3 дв.',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//открытый кузов//пикап//седан//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//цельнометаллический фургон',
#  'бортовой грузовик//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//джип/suv 5 дв.//пикап//цельнометаллический фургон',
#  'бортовой грузовик//цельнометаллический фургон//шасси',
#  'автобус//джип/suv 5 дв.//пикап//цельнометаллический фургон//шасси',
#  'цельнометаллический фургон//шасси',
#  'джип/suv 5 дв.//пикап//седан',
#  'автобус//джип/suv 5 дв.//лифтбек//минивэн//пикап//седан//универсал//цельнометаллический фургон',
#  'купе//лифтбек//универсал//хэтчбек 3 дв.',
#  'лифтбек//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//седан//хэтчбек 3 дв.',
#  'джип/suv 3 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.',
#  'минивэн//цельнометаллический фургон',
#  'шасси',
#  'минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'бортовой грузовик//лифтбек//минивэн//седан//универсал//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//минивэн//седан//универсал//цельнометаллический фургон//шасси',
#  'лифтбек//минивэн//седан//универсал//хэтчбек 5 дв.',
#  'лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'джип/suv 3 дв.//купе//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//минивэн//цельнометаллический фургон//шасси',
#  'лифтбек//хэтчбек 3 дв.',
#  'автобус//бортовой грузовик//лифтбек//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон',
#  'купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'лифтбек//минивэн//седан//универсал',
#  'автобус//бортовой грузовик//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'купе//лифтбек//хэтчбек 3 дв.',
#  'хэтчбек',
#  'джип/suv 5 дв.//минивэн//седан//универсал//хэтчбек 5 дв.',
#  'купе//минивэн//седан//универсал',
#  'купе//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//минивэн',
#  'седан//универсал//хэтчбек 3 дв.',
#  'лифтбек//седан//хэтчбек 3 дв.',
#  'купе//седан//универсал//хэтчбек 3 дв.',
#  'купе//седан//универсал//хэтчбек 5 дв.',
#  'купе//хэтчбек 3 дв.',
#  'купе//универсал//хэтчбек 3 дв.',
#  'лифтбек//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//минивэн',
#  'бортовой грузовик//минивэн//цельнометаллический фургон',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//седан',
#  'автобус',
#  'джип/suv 5 дв.//купе//минивэн//седан//хэтчбек 5 дв.',
#  'автобус//минивэн',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//лифтбек//минивэн//седан//седельный тягач//фургон//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//минивэн//седельный тягач//фургон//цельнометаллический фургон//шасси',
#  'бортовой грузовик//фургон//шасси',
#  'автобус//джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//джип/suv 5 дв.',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//седан//седельный тягач//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//седан//универсал',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//цельнометаллический фургон',
#  'джип/suv 5 дв.//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//бортовой грузовик//минивэн//седельный тягач//цельнометаллический фургон',
#  'купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//седан',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//седан//седельный тягач//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//седан//седельный тягач//универсал//фургон//хэтчбек 3 дв.//хэтчбек 5 дв.//шасси',
#  'джип/suv 5 дв.//купе//седан//универсал//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//купе//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//бортовой грузовик//минивэн//седельный тягач//фургон//шасси',
#  'автобус//бортовой грузовик//минивэн//фургон//шасси',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//седан//цельнометаллический фургон',
#  'джип/suv 5 дв.//купе//минивэн//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//лифтбек//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//бортовой грузовик//минивэн',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//джип/suv 5 дв.//минивэн',
#  'купе//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//седан//универсал//хэтчбек 5 дв.',
#  'бортовой грузовик',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//минивэн//седельный тягач//цельнометаллический фургон',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//лифтбек//минивэн//седан//седельный тягач//универсал//фургон//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//седан//седельный тягач//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'джип/suv 5 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//лифтбек//минивэн//седан//универсал//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//минивэн//седан//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//седан//универсал',
#  'джип/suv 3 дв.//джип/suv 5 дв.//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//лифтбек//минивэн//седан//универсал',
#  'джип/suv 3 дв.//джип/suv 5 дв.//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'пикап//седан//универсал',
#  'джип/suv 5 дв.//лифтбек//минивэн//седан//универсал',
#  'джип/suv 5 дв.//минивэн//седан//универсал',
#  'джип/suv 3 дв.//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//лифтбек//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//седан//хэтчбек 3 дв.',
#  'автобус//седан//универсал//цельнометаллический фургон',
#  'автобус//купе//открытый кузов//седан//универсал//цельнометаллический фургон',
#  'автобус//бортовой грузовик//купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон//шасси',
#  'автобус//седан//цельнометаллический фургон',
#  'автобус//джип/suv 3 дв.//джип/suv 5 дв.//купе//седан//универсал//цельнометаллический фургон',
#  'автобус//бортовой грузовик//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//открытый кузов//седан//универсал//цельнометаллический фургон//шасси',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//открытый кузов//седан',
#  'автобус//бортовой грузовик//купе//минивэн//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//цельнометаллический фургон//шасси',
#  'автобус//цельнометаллический фургон//шасси',
#  'автобус//купе//седан//универсал//цельнометаллический фургон',
#  'автобус//купе//минивэн//хэтчбек 3 дв.',
#  'джип/suv 5 дв.//купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.',
#  'джип/suv 5 дв.//купе//минивэн//седан//универсал',
#  'автобус//бортовой грузовик//купе//седан//универсал//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//седан//универсал//цельнометаллический фургон//шасси',
#  'автобус//купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//купе//минивэн//открытый кузов//седан//седельный тягач//универсал//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//открытый кузов//седан//седельный тягач//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//минивэн//седан//цельнометаллический фургон//шасси',
#  'купе//минивэн//седан//универсал//хэтчбек 3 дв.',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//открытый кузов//седан//седельный тягач//универсал//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//купе//минивэн//открытый кузов//седан//универсал//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 5 дв.//купе//минивэн//открытый кузов//пикап//седан//седельный тягач//универсал//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'автобус//минивэн//цельнометаллический фургон//шасси',
#  'автобус//бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//седан//универсал//цельнометаллический фургон//шасси',
#  'автобус//джип/suv 5 дв.//купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'джип/suv 5 дв.//седан//универсал//хэтчбек 5 дв.',
#  'автобус//бортовой грузовик//купе//открытый кузов//седан//универсал//цельнометаллический фургон',
#  'автобус//купе//минивэн//открытый кузов//седан//универсал',
#  'автобус//бортовой грузовик//купе//открытый кузов//седан//универсал//цельнометаллический фургон//шасси',
#  'купе//минивэн//открытый кузов//седан//универсал',
#  'автобус//купе//минивэн//седан//универсал//хэтчбек 3 дв.',
#  'автобус//бортовой грузовик//купе//седан//универсал//хэтчбек 3 дв.//цельнометаллический фургон//шасси',
#  'автобус//универсал//цельнометаллический фургон',
#  'минивэн//пикап',
#  'джип/suv 3 дв.//джип/suv 5 дв.//лифтбек//минивэн//пикап//седан//универсал',
#  'купе//пикап',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//пикап//седан//универсал//хэтчбек 3 дв.',
#  'купе//лифтбек//минивэн//седан',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//пикап//хэтчбек 3 дв.',
#  'бортовой грузовик//цельнометаллический фургон',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'джип/suv 3 дв.//минивэн//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 3 дв.//цельнометаллический фургон',
#  'джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап//седан//универсал//цельнометаллический фургон',
#  'джип/suv 3 дв.//минивэн',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//седан',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//открытый кузов//седан',
#  'лифтбек//минивэн//седан',
#  'минивэн//седан//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//минивэн//седан',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'бортовой грузовик//джип/suv 5 дв.//купе//минивэн//открытый кузов//седан//универсал',
#  'бортовой грузовик//купе//лифтбек//минивэн//седан//универсал',
#  'джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//седан//хэтчбек 3 дв.',
#  'бортовой грузовик//пикап//седан//шасси',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап//седан//универсал',
#  'бортовой грузовик//минивэн//пикап',
#  'бортовой грузовик//пикап',
#  'купе//открытый кузов//хэтчбек 3 дв.',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//пикап',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//минивэн//пикап//седан//универсал//хэтчбек 3 дв.',
#  'минивэн//пикап//седан',
#  'бортовой грузовик//шасси',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//купе//минивэн//пикап//седан//универсал//хэтчбек 3 дв.',
#  'открытый кузов//универсал//хэтчбек 5 дв.',
#  'открытый кузов//седан//универсал//хэтчбек 5 дв.',
#  'пикап//универсал',
#  'автобус//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'автобус//минивэн//цельнометаллический фургон',
#  'автобус//купе//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон',
#  'автобус//минивэн//седан//универсал//цельнометаллический фургон',
#  'купе//открытый кузов//седан//универсал//хэтчбек 5 дв.',
#  'купе//открытый кузов//седан//хэтчбек 5 дв.',
#  'купе//лифтбек//минивэн//универсал//хэтчбек 5 дв.',
#  'купе//лифтбек//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//универсал//хэтчбек 3 дв.',
#  'джип/suv 5 дв.//купе//лифтбек//минивэн//открытый кузов//пикап//седан//седельный тягач//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.//цельнометаллический фургон//шасси',
#  'пикап//универсал//хэтчбек 5 дв.',
#  'пикап//хэтчбек 5 дв.',
#  'лифтбек//седан//универсал//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//универсал//хэтчбек 5 дв.',
#  'лифтбек//пикап//универсал//хэтчбек 5 дв.',
#  'универсал//хэтчбек 5 дв.//цельнометаллический фургон',
#  'лифтбек//седан//универсал//хэтчбек 5 дв.',
#  'лифтбек//универсал//хэтчбек 5 дв.//цельнометаллический фургон',
#  'универсал//цельнометаллический фургон',
#  'бортовой грузовик//минивэн//фургон',
#  'бортовой грузовик//джип/suv 5 дв.//минивэн//седан//универсал',
#  'бортовой грузовик//фургон',
#  'бортовой грузовик//минивэн//фургон//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 5 дв.//купе//минивэн//седан//универсал',
#  'бортовой грузовик//купе//минивэн//седан//универсал//фургон//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//минивэн//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//универсал',
#  'бортовой грузовик//минивэн//седан//универсал//фургон//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//минивэн//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//седан//универсал//хэтчбек 3 дв.',
#  'джип/suv 3 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//джип/suv 5 дв.//хэтчбек 5 дв.',
#  'джип/suv 3 дв.//открытый кузов',
#  'джип/suv 3 дв.//открытый кузов//пикап',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//минивэн//открытый кузов//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 3 дв.//минивэн//открытый кузов//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'бортовой грузовик//джип/suv 3 дв.//джип/suv 5 дв.//хэтчбек 5 дв.',
#  'джип/suv 5 дв.//открытый кузов',
#  'джип/suv 3 дв.//джип/suv 5 дв.//открытый кузов',
#  'джип/suv 3 дв.//джип/suv 5 дв.//седан//хэтчбек 5 дв.',
#  'лифтбек//минивэн',
#  'лифтбек//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//минивэн',
#  'купе//минивэн//седан',
#  'минивэн//седан//универсал//хэтчбек 3 дв.',
#  'лифтбек//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'открытый кузов//пикап//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//открытый кузов//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'автобус//джип/suv 5 дв.//минивэн//седан//универсал//цельнометаллический фургон//шасси',
#  'джип/suv 5 дв.//минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'пикап//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'минивэн//открытый кузов//седан//универсал//хэтчбек 3 дв.',
#  'автобус//бортовой грузовик//купе//седан//универсал//хэтчбек 3 дв.',
#  'джип/suv 5 дв.//открытый кузов//седан//универсал//шасси',
#  'джип/suv 5 дв.//седан//универсал//шасси',
#  'автобус//бортовой грузовик//седан//хэтчбек 3 дв.//хэтчбек 5 дв.',
#  'купе//открытый кузов//седан//универсал//шасси',
#  'автобус//бортовой грузовик',
#  'седельный тягач//шасси']

# %%
# большое кол-во признаков через //, которые могут путать модель, а так же не легковые авто. удаляем
# список нужных типов кузова:
valid = [
    "купе", "лифтбек", "открытый", "открытый кузов",
    "седан", "хэтчбек 3 дв.", "хэтчбек 5 дв.",
    "универсал", "минивэн", "джип/suv 5 дв.", "джип/suv 3 дв."
]

# список для исключения (грузовые и спецтехника)
invalid = [
    "автобус", "грузовик", "бортовой", "шасси", "пикап", 
    "цельнометаллический", "фургон", "седельный тягач", "рефрижератор"
]

# удалим строки с //
df = df[~df["Тип кузова"].str.contains("//", na=False)]

# удалим строки с грузовым авто
mask_invalid = df["Тип кузова"].str.contains("|".join(invalid), case=False, na=False)
df = df[~mask_invalid]

# оставляем только нужные легковые кузовы
df = df[df["Тип кузова"].isin(valid)]

df["Тип кузова"].value_counts()
# Out:
# Тип кузова
# седан             4896968
# джип/suv 5 дв.    2496446
# хэтчбек 5 дв.     2057755
# универсал          948642
# минивэн            760675
# джип/suv 3 дв.     233784
# лифтбек            230988
# хэтчбек 3 дв.      160312
# купе                72735
# открытый             4233
# открытый кузов       3922
# Name: count, dtype: int64

# %%
# поскольку у нас огромное кол-во данных (12_147_688), можем просто удалить строки с пропущенными данными хотя бы в одной колонке
req_col = list(df.columns)
df = df.dropna(subset=req_col)
df.shape
# Out:
# (11189638, 16)

# %%
total_nan = df.isnull().sum().sum()
total_nan # в датасете теперь отсутсвуют пропуски
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(15,5))
plt.hist(df["Цена"], bins=100)
plt.ticklabel_format(style='plain', axis='y')
plt.ticklabel_format(style='plain', axis='x')# показывает обычные числа на оси Y
plt.xlabel("Цена, руб.")
plt.ylabel("Количество автомобилей")
plt.show()
# по гистограмме можно заметить, что есть очень малое кол-во аномально дорогих авто. это может существенно понизить точность предсказаний

# %%
# обрежем цену с 50_000 до 10_000_000
df = df[(df["Цена"] >= 50_000) & (df["Цена"] <= 10_000_000)]

# уберем новые авто с низким пробегом
df = df[df["Пробег"] > 2_000]

# удалим аномалии с объёмом двигателя меньше 0,6 л
df = df[(df['Объем двигателя'] >= 0.6) & (df['Объем двигателя'] < 8)]

df = df[(df['Тип двигателя'] != 'электро') & (df['Тип двигателя'] != 'газ/бензин') & (df['Тип двигателя'] != 'ГБО') & (df['Тип двигателя'] != 'газ')]
print(df['Тип двигателя'].unique())
#print(df[df['Тип двигателя'] == 'ГБО'])

df = df[(df['Название машины'] != 'Ford Focus') & (df['Дата размещения объявления'] != '2023-05-21')]
# Out:
# <StringArray>
# ['бензин', 'дизель']
# Length: 2, dtype: str

# %%
plt.figure(figsize=(15,5))
plt.hist(df["Цена"], bins=100)
plt.ticklabel_format(style='plain', axis='y')
plt.ticklabel_format(style='plain', axis='x')# показывает обычные числа на оси Y
plt.xlabel("Цена, руб.")
plt.ylabel("Количество автомобилей")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10411892 entries, 1 to 12147687
# Data columns (total 16 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   Название машины             str
#  1   Год                         float64
#  2   Дата размещения объявления  str
#  3   Цена                        float64
#  4   Объем двигателя             float64
#  5   Тип двигателя               str
#  6   Мощность                    float64
#  7   Коробка передач             str
#  8   Привод                      str
#  9   Пробег                      float64
#  10  Руль                        str
#  11  Поколение                   float64
#  12  Рестайлинг                  float64
#  13  Тип кузова                  str
#  14  Метка                       str
#  15  Город                       str
# dtypes: float64(7), str(9)
# memory usage: 1.3 GB

# %%
# преобразуем колонку с датой в соответствующий тип и уберем данные до 18го года
df["Дата размещения объявления"] = pd.to_datetime(df["Дата размещения объявления"], format='%Y-%m-%d')
df = df[df["Дата размещения объявления"].dt.year >= 2018]

# %%
df["Дата размещения объявления"] = pd.to_datetime(df["Дата размещения объявления"])
df["Год объявления"] = df["Дата размещения объявления"].dt.year
df["Месяц объявления"] = df["Дата размещения объявления"].dt.month
df["Возраст авто"] = df["Год объявления"] - df["Год"]
df = df.drop("Дата размещения объявления", axis=1)

# %%
df_main = df.sample(n=1_000_000, random_state=42)
df_main = df_main.reset_index(drop=True)
df_main.info()
df_main.to_csv("data/drom_archive_cleaned_2018-2025.csv", index=False)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Название машины   1000000 non-null  str
#  1   Год               1000000 non-null  float64
#  2   Цена              1000000 non-null  float64
#  3   Объем двигателя   1000000 non-null  float64
#  4   Тип двигателя     1000000 non-null  str
#  5   Мощность          1000000 non-null  float64
#  6   Коробка передач   1000000 non-null  str
#  7   Привод            1000000 non-null  str
#  8   Пробег            1000000 non-null  float64
#  9   Руль              1000000 non-null  str
#  10  Поколение         1000000 non-null  float64
#  11  Рестайлинг        1000000 non-null  float64
#  12  Тип кузова        1000000 non-null  str
#  13  Метка             1000000 non-null  str
#  14  Город             1000000 non-null  str
#  15  Год объявления    1000000 non-null  int32
#  16  Месяц объявления  1000000 non-null  int32
#  17  Возраст авто      1000000 non-null  float64
# dtypes: float64(8), int32(2), str(8)
# memory usage: 129.7 MB
